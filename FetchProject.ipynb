# %% [markdown]
# # <u>Fetch Project: Python code

# %%
import pandas as pd

# %% [markdown]
# ## Using pandas to load CSVs into their own DataFrame tables

# %%
products = pd.read_csv('PRODUCTS_TAKEHOME.csv')
transactions = pd.read_csv('TRANSACTION_TAKEHOME.csv')
users = pd.read_csv('USER_TAKEHOME.csv')

# %% [markdown]
# ## Checking all Data Tables
# Checking each one of the tables below to see what they look like and notice any initial errors

# %%
products
# Out:
#                CATEGORY_1                                CATEGORY_2  \
# 0       Health & Wellness                             Sexual Health
# 1                  Snacks                             Puffed Snacks
# 2       Health & Wellness                                 Hair Care
# 3       Health & Wellness                                 Oral Care
# 4       Health & Wellness                    Medicines & Treatments
# ...                   ...                                       ...
# 845547  Health & Wellness  Topical Muscle & Joint Relief Treatments
# 845548             Snacks                                   Cookies
# 845549             Snacks                                     Candy
# 845550             Snacks                              Nuts & Seeds
# 845551  Health & Wellness                                 First Aid
#
#                          CATEGORY_3 CATEGORY_4  \
# 0       Conductivity Gels & Lotions        NaN
# 1              Cheese Curls & Puffs        NaN
# ...

# %%
transactions
# Out:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 0      0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1      0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2      00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3      000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4      00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
# ...                                     ...           ...
# 49995  b5cd61a9-8033-4913-a5c4-fb3f65e3a321    2024-08-21
# 49996  e1b2f634-c9ad-4152-b662-4b22efc25862    2024-08-11
# 49997  b07ef8dd-e444-40a2-819b-f74a3e5f1ae7    2024-07-11
# 49998  42475141-bef4-4df2-aa37-72577e2512bb    2024-06-18
# 49999  3a179c4e-46f2-4126-b3d2-3514afc23a3e    2024-08-07
#
#                        SCAN_DATE     STORE_NAME                   USER_ID  \
# 0      2024-08-21 14:19:06.539 Z        WALMART  63b73a7f3d310dceeabd4758
# 1      2024-07-20 09:50:24.206 Z           ALDI  62c08877baa38d1a1f6c211a
# ...

# %%
users
# Out:
#                              ID               CREATED_DATE  \
# 0      5ef3b4f17053ab141787697d  2020-06-24 20:17:54.000 Z
# 1      5ff220d383fcfc12622b96bc  2021-01-03 19:53:55.000 Z
# 2      6477950aa55bb77a0e27ee10  2023-05-31 18:42:18.000 Z
# 3      658a306e99b40f103b63ccf8  2023-12-26 01:46:22.000 Z
# 4      653cf5d6a225ea102b7ecdc2  2023-10-28 11:51:50.000 Z
# ...                         ...                        ...
# 99995  61fc06d41febf771966da8fa  2022-02-03 16:46:12.000 Z
# 99996  6391e7ef90ad5449ec5f782d  2022-12-08 13:34:39.000 Z
# 99997  637d5efdd6f2a49c49934dcb  2022-11-22 23:45:05.000 Z
# 99998  5f0de23b05d8a6147dc0cafa  2020-07-14 16:50:04.000 Z
# 99999  5e7ab436905e9512ff44abc8  2020-03-25 01:30:30.000 Z
#
#                       BIRTH_DATE STATE LANGUAGE  GENDER
# 0      2000-08-11 00:00:00.000 Z    CA   es-419  female
# 1      2001-09-24 04:00:00.000 Z    PA       en  female
# 2      1994-10-28 00:00:00.000 Z    FL   es-419  female
# ...

# %% [markdown]
# ## Checking all Date columns
# Checking the data type of the contents in all the date columns: SCAN_DATE, CREATED_DATE, and BIRTH_DATE

# %%
type(transactions['SCAN_DATE'].iloc[0])
# Out:
# str

# %%
type(users['CREATED_DATE'].iloc[0])
# Out:
# str

# %%
type(users['BIRTH_DATE'].iloc[0])
# Out:
# str

# %% [markdown]
# ## GENDER column non-unique entries

# %%
users['GENDER'].unique()
# Out:
# array(['female', nan, 'male', 'non_binary', 'transgender',
#        'prefer_not_to_say', 'not_listed', 'Non-Binary', 'unknown',
#        'not_specified', "My gender isn't listed", 'Prefer not to say'],
#       dtype=object)

# %% [markdown]
# ## Checking empty cells
# Checking how many empty cells are in each column of each table

# %%
products.isna().sum()
# Out:
# CATEGORY_1         111
# CATEGORY_2        1424
# CATEGORY_3       60566
# CATEGORY_4      778093
# MANUFACTURER    226474
# BRAND           226472
# BARCODE           4025
# dtype: int64

# %%
transactions.isna().sum()
# Out:
# RECEIPT_ID           0
# PURCHASE_DATE        0
# SCAN_DATE            0
# STORE_NAME           0
# USER_ID              0
# BARCODE           5762
# FINAL_QUANTITY       0
# FINAL_SALE           0
# dtype: int64

# %%
users.isna().sum()
# Out:
# ID                  0
# CREATED_DATE        0
# BIRTH_DATE       3675
# STATE            4812
# LANGUAGE        30508
# GENDER           5892
# dtype: int64

# %% [markdown]
# ## Calculating percent of empty rows in column CATEGORY_4
# (empty rows in CATEGORY_4)/(number of rows in products table)

# %%
778093/845552
# Out:
# 0.9202189812099079

# %% [markdown]
# ## FINAL_SALE column has "empty" rows
# Showing that FINAL_SALE column has rows which only contain an empty space

# %%
transactions[transactions['FINAL_SALE']==' ']
# Out:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 0      0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 2      00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 4      00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
# 6      000550b2-1480-4c07-950f-ff601f242152    2024-07-06
# 8      000e1d35-15e5-46c6-b6b3-33653ed3d27e    2024-08-13
# ...                                     ...           ...
# 24990  ffeb1ff4-0db9-4cb9-9574-20ec2db3e5ad    2024-08-25
# 24992  ffec42ba-c71d-44da-b8d0-eb529632e87a    2024-06-17
# 24994  fff15a3d-25ea-4c36-b84a-91eb4157daf9    2024-07-19
# 24996  fff6c6c8-e002-4262-85ea-25849d9721db    2024-08-30
# 24998  fffbfb2a-7c1f-41c9-a5da-628fa7fcc746    2024-07-28
#
#                        SCAN_DATE   STORE_NAME                   USER_ID  \
# 0      2024-08-21 14:19:06.539 Z      WALMART  63b73a7f3d310dceeabd4758
# 2      2024-08-19 15:38:56.813 Z      WALMART  60842f207ac8b7729e472020
# ...

# %% [markdown]
# ## FINAL_QUANTITY column has strange entries
# FINAL_QUANTITY column has a 1.00 as a string or a 'zero'

# %%
transactions[(transactions['FINAL_QUANTITY']=='1.00') | (transactions['FINAL_QUANTITY']=='zero')]
# Out:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 0      0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1      0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2      00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3      000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4      00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
# ...                                     ...           ...
# 49994  6cdf3c1a-78b3-4fb0-85fd-52e2f5b4731c    2024-06-26
# 49996  e1b2f634-c9ad-4152-b662-4b22efc25862    2024-08-11
# 49997  b07ef8dd-e444-40a2-819b-f74a3e5f1ae7    2024-07-11
# 49998  42475141-bef4-4df2-aa37-72577e2512bb    2024-06-18
# 49999  3a179c4e-46f2-4126-b3d2-3514afc23a3e    2024-08-07
#
#                        SCAN_DATE     STORE_NAME                   USER_ID  \
# 0      2024-08-21 14:19:06.539 Z        WALMART  63b73a7f3d310dceeabd4758
# 1      2024-07-20 09:50:24.206 Z           ALDI  62c08877baa38d1a1f6c211a
# ...

# %% [markdown]
# ## FINAL_QUANTITY has non-integers
# FINAL_QUANTITY column has non-integer values, which confuse me because I'm not sure if it's an error, referring to a product's weight or something else

# %%
transactions['FINAL_QUANTITY'].value_counts()
# Out:
# FINAL_QUANTITY
# 1.00    35698
# zero    12500
# 2.00     1285
# 3.00      184
# 4.00      139
#         ...
# 6.22        1
# 1.22        1
# 1.23        1
# 2.57        1
# 2.27        1
# Name: count, Length: 87, dtype: int64

# %% [markdown]
# # FINAL_QUANTITY column has strings
# Showing that the FINAL_QUANTITY column has strings for its data type, which is unusual since its only supposed to have numbers

# %%
type(transactions['FINAL_QUANTITY'].iloc[0])
# Out:
# str
